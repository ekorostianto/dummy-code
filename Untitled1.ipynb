# %%
library(rgdal)  
library(raster)
library(rasterVis)
library(viridis)
wd <- "D:/College/Semester8/data/analisa/grace_rl05" # this will depend on your local environment environment
# be sure that the downloaded file is in this directory
setwd(wd)
# import raster
DSM_HARV <- raster(paste0(wd,"gracegrd_200510.csv.tif"))
plot(DSM_HARV,
     main="Oktober 2005",
     xlab = "Longitude", 
     ylab = "Latitude", col=plasma(256))
aoiBoundary_HARV <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
plot(aoiBoundary_HARV, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "linebengawansolobrantas"
# with 85 features
# It has 23 fields
# Plot with title "Oktober 2005"

# %%
DSM_HARV_df <- DSM_HARV_df mutate(fct_elevation = cut(DSM_HARV, breaks = 3))
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:28: unexpected symbol
# 1: DSM_HARV_df <- DSM_HARV_df mutate
#                                ^
# Traceback:

# %%
library("png")
library("raster")
plot(0:2, 0:2, type = "n", xaxt = "n", yaxt = "n", xlab = "", ylab = "")
rasterImage(readPNG(source="D:/College/Semester8/data/analisa/grace_rl05/plot_gracerl05masked/Gambar1.png"), 0, 1, 1, 2)
rasterImage(readPNG(source="D:/College/Semester8/data/analisa/grace_rl05/plot_gracerl05masked/Gambar2.png"), 1, 1, 2, 2)
rasterImage(readPNG(source="D:/College/Semester8/data/analisa/grace_rl05/plot_gracerl05masked/Gambar3.png"), 0, 0, 1, 1)
rasterImage(readPNG(source="D:/College/Semester8/data/analisa/grace_rl05/plot_gracerl05masked/Gambar4.png"), 1, 0, 2, 1)
# Out:
# Loading required package: sp
# plot without title

# %%
DSM_HARV
# Out:
# class       : RasterLayer
# dimensions  : 5, 9, 45  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.625, 112.875, -8.125, -6.875  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs +ellps=WGS84 +towgs84=0,0,0
# data source : D:/College/Semester8/data/analisa/grace_rl05/masked/gracegrd_200510.csv.tif
# names       : gracegrd_200510.csv
# values      : -46.85312, 0  (min, max)

# %%
library(rgdal)  
library(raster)
library(viridis)
wd <- "D:/College/Semester8/data/analisa/grace_rl05/gracerl05_grd/" # this will depend on your local environment environment
# be sure that the downloaded file is in this directory
setwd(wd)
# import raster
GWSGLDAS <- raster(paste0(wd,"GSM_200504.grd"))
batasbasin <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
masked <- mask(x = GWSGLDAS, mask = batasbasin)
cropped <- crop(x = masked, y = extent(batasbasin))
DEMDAS <- raster("D:/College/Semester8/data/das/DEMDAS.tif")
plot(DEMDAS,
     main="Anomali EWH Maret 2012 (mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude")
plot(batasbasin, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)
cropped
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "linebengawansolobrantas"
# with 85 features
# It has 23 fields
# class       : RasterLayer
# dimensions  : 6, 10, 60  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.375, 112.875, -8.375, -6.875  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# data source : in memory
# names       : z
# values      : -7.714502, 13.82983  (min, max)
# Plot with title "Anomali EWH Maret 2012 (mm)
#  Basin Bengawan Solo dan Brantas"

# %%
library(rgdal)  
library(raster)
library(viridis)
wd <- "D:/College/Semester8/data/analisa/gws/monthly/" # this will depend on your local environment environment
# be sure that the downloaded file is in this directory
setwd(wd)
# import raster
GWSGLDAS <- raster(paste0(wd,"GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20151001-20151031.180W_60S_180E_90N.tif"))
batasbasin <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
masked <- mask(x = GWSGLDAS, mask = batasbasin)
cropped <- crop(x = masked, y = extent(batasbasin))
plot(cropped,
     main="Anomali Groundwater Storage Oktober 2015 (mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude", 
     col=plasma(256))
plot(batasbasin, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "linebengawansolobrantas"
# with 85 features
# It has 23 fields
# Plot with title "Anomali Groundwater Storage Oktober 2015 (mm)
#  Basin Bengawan Solo dan Brantas"

# %%
cropped
# Out:
# class       : RasterLayer
# dimensions  : 6, 10, 60  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.375, 112.875, -8.375, -6.875  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# data source : in memory
# names       : z
# values      : -1.639938, 0.1181878  (min, max)

# %%
library(rgdal)  
library(raster)
library(viridis)
wd <- "D:/College/Semester8/data/analisa/gws/monthly/" # this will depend on your local environment environment
# be sure that the downloaded file is in this directory
setwd(wd)
# import raster
EWHGrace <- raster(paste0(wd,"GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20051001-20051031.180W_60S_180E_90N.tif"))
batasbasin <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
masked <- mask(x = EWHGrace, mask = batasbasin)
cropped <- crop(x = masked, y = extent(batasbasin))
plot(cropped,
     main="Simpanan Air Tanah GWS GLDAS Oktober 2005 (mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude", 
     col=viridis(256),
     zlim=c(390,1367)
    )
plot(batasbasin, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)
cropped
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "linebengawansolobrantas"
# with 85 features
# It has 23 fields
# class       : RasterLayer
# dimensions  : 6, 10, 60  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.5, 113, -8.25, -6.75  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs +ellps=WGS84 +towgs84=0,0,0
# data source : in memory
# names       : GIOVANNI.g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20051001.20051031.180W_60S_180E_90N
# values      : 454.6868, 1067.395  (min, max)
# Plot with title "Simpanan Air Tanah GWS GLDAS Oktober 2005 (mm)
#  Basin Bengawan Solo dan Brantas"

# %%
cropped
# Out:
# class       : RasterLayer
# dimensions  : 6, 10, 60  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.375, 112.875, -8.375, -6.875  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# data source : in memory
# names       : z
# values      : -45.21136, -28.77351  (min, max)

# %%
hist(cropped,xlab = "EWH (mm)", ylab = "Frequency",
     col = "springgreen")
# Out:
# Plot with title "z"

# %%
min(cropped)
# Out:
# class       : RasterLayer
# dimensions  : 6, 10, 60  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 110.375, 112.875, -8.375, -6.875  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# data source : in memory
# names       : z
# values      : -50.26003, -22.35806  (min, max)

# %% [raw]
# cropped

# %%
EWHGrace
# Out:
# class       : RasterLayer
# dimensions  : 721, 1440, 1038240  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : -0.125, 359.875, -90.125, 90.125  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# data source : D:/College/Semester8/data/analisa/grace_rl05/gracerl05_grd/GSM_201509.grd
# names       : z
# zvar        : z

# %%
library(ggplot2)
library(dplyr) # easier data wrangling 
library(viridis) # colour blind friendly palette, works in B&W also
library(Interpol.T) #  will generate a large dataset on initial load
library(lubridate) # for easy date manipulation
library(ggExtra) # because remembering ggplot theme options is beyond me
library(tidyr) 
 
 
data <- data(Trentino_hourly_T,package = "Interpol.T")
 
names(h_d_t)[1:5]<- c("stationid","date","hour","temp","flag")
df <- tbl_df(h_d_t) %>%
  filter(stationid =="T0001")
 
df <- df %>% mutate(year = year(date),
                  month = month(date, label=TRUE),
                  day = day(date))
  
df$date<-ymd(df$date) # not necessary for plot but 
#useful if you want to do further work with the data
 
#cleanup
rm(list=c("h_d_t","mo_bias","Tn","Tx",
          "Th_int_list","calibration_l",
          "calibration_shape","Tm_list"))
 
 
#create plotting df
df <-df %>% select(stationid,day,hour,month,year,temp)%>%
        fill(temp) #optional - see note below
 
# Re: use of fill
# This code is for demonstrating a visualisation technique
# There are 5 missing hourly values in the dataframe.
 
# see the original plot here (from my ggplot demo earlier this year) to see the white spaces where the missing values occcur:
# https://github.com/johnmackintosh/ggplotdemo/blob/master/temp8.png 
 
# I used 'fill' from  tidyr to take the prior value for each missing value and replace the NA
# This is a quick fix for the blog post only - _do not_ do this with your real world data
 
# Should really use either use replace_NA or complete(with fill)in tidyr 
# OR 
# Look into more specialist way of replacing these missing values -e.g. imputation.
 
 
 
statno <-unique(df$stationid)
 
 
 
######## Plotting starts here#####################
p <-ggplot(df,aes(day,hour,fill=temp))+
  geom_tile(color= "white",size=0.1) + 
  scale_fill_viridis(name="Hrly Temps C",option ="C")
p <-p + facet_grid(year~month)
p <-p + scale_y_continuous(trans = "reverse", breaks = unique(df$hour))
p <-p + scale_x_continuous(breaks =c(1,10,20,31))
p <-p + theme_minimal(base_size = 8)
p <-p + labs(title= paste("Hourly Temps - Station",statno), x="Day", y="Hour Commencing")
p <-p + theme(legend.position = "bottom")+
  theme(plot.title=element_text(size = 14))+
  theme(axis.text.y=element_text(size=6)) +
  theme(strip.background = element_rect(colour="white"))+
  theme(plot.title=element_text(hjust=0))+
  theme(axis.ticks=element_blank())+
  theme(axis.text=element_text(size=7))+
  theme(legend.title=element_text(size=8))+
  theme(legend.text=element_text(size=6))+
  removeGrid()#ggExtra
 
# you will want to expand your plot screen before this bit!
p #awesomeness
# Out:
# Attaching package: 'dplyr'
#
# The following object is masked from 'package:gridExtra':
#
#     combine
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# Error in library(Interpol.T): there is no package called 'Interpol.T'
# Traceback:
#
# 1. library(Interpol.T)

# %%
library(raster)


ff <- list.files("D:/College/Semester8/data/analisa/gws/monthly", pattern = "\\.tif$", full=TRUE)
s <- stack(ff)

poly <- shapefile("D:/College/Semester8/data/das/batasbasin.shp")

ex <- extract(s, poly, min, na.rm=TRUE)
write.csv(ex, "D:/College/Semester8/data/analisa/zonal_statistics/listMinimumGWS.csv")

# %%
library(raster)
library(rgdal)
library(rasterVis)
library(RColorBrewer)

ff <- list.files("D:/College/Semester8/data/analisa/grace_rl05/gracerl05_grd/", pattern = "\\.grd$", full=TRUE)
s <- stack(ff)
jumlah <- calc(s, sum)
vtahun <- (jumlah/length(ff))*12

library(rgdal)
batasbasin <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
masked <- mask(x = vtahun, mask = batasbasin)
cropped <- crop(x = masked, y = extent(batasbasin))
cols <- colorRampPalette(brewer.pal(9,"RdBu"))
levelplot(cropped,
     main="Kecepatan rata2 per tahun EWH(mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude", 
     col.regions=cols
    )
'plot(batasbasin, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)'
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# [1] "plot(batasbasin, col=\"transparent\", border=\"black\", lwd=1, add = TRUE)\nlinesungai <- readOGR(dsn=path.expand(\"D:/College/Semester8/data/das\"),\n                            layer=\"linebengawansolobrantas\")\nplot(linesungai, col=\"blue\", border=\"black\", lwd=1, add = TRUE)"
# plot without title

# %%
library(rasterVis)
plot(cropped,
     main="Kecepatan rata2 per tahun EWH(mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude", 
     col="Reds"
    )
# Out:
# Error in graphics::rasterImage(x, e[1], e[3], e[2], e[4], interpolate = interpolate): invalid color name 'Reds'
# Traceback:
#
# 1. plot(cropped, main = "Kecepatan rata2 per tahun EWH(mm) \n Basin Bengawan Solo dan Brantas",
#  .     xlab = "Longitude", ylab = "Latitude", col = "Reds")
# 2. plot(cropped, main = "Kecepatan rata2 per tahun EWH(mm) \n Basin Bengawan Solo dan Brantas",
#  .     xlab = "Longitude", ylab = "Latitude", col = "Reds")
# 3. .local(x, y, ...)
# 4. .plotraster2(x, col = col, maxpixels = maxpixels, add = add,
#  .     ext = ext, interpolate = interpolate, colNA = colNA, main = main,
#  .     addfun = addfun, facvar = facvar, alpha = alpha, npretty = npretty,
#  .     ...)
# 5. .rasterImagePlot(object, col = col, xlab = xlab, ylab = ylab,
#  .     add = add, colNA = colNA, main = main, alpha = alpha, ...)
# 6. graphics::rasterImage(x, e[1], e[3], e[2], e[4], interpolate = interpolate)
# Plot with title "Kecepatan rata2 per tahun EWH(mm)
#  Basin Bengawan Solo dan Brantas"

# %%
vtahun
# Out:
# class       : RasterLayer
# dimensions  : 70, 186, 13020  (nrow, ncol, ncell)
# resolution  : 0.25, 0.25  (x, y)
# extent      : 94.75, 141.25, -11.25, 6.25  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs +ellps=WGS84 +towgs84=0,0,0
# data source : in memory
# names       : layer
# values      : 5294.364, 42290.43  (min, max)

# %%
library(raster)
library(rgdal)
library(viridis)

ff <- list.files("D:/College/Semester8/data/analisa/gws/monthly", pattern = "\\.tif$", full=TRUE)
s <- stack(ff)
jumlah <- calc(s, sum)
vtahun <- (jumlah/length(ff))*12

library(rgdal)
batasbasin <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="DasBrantasBengawansolo")
masked <- mask(x = vtahun, mask = batasbasin)
cropped <- crop(x = masked, y = extent(batasbasin))
plot(cropped,
     main="Kecepatan rata2 per tahun GWS GLDAS(mm) \n Basin Bengawan Solo dan Brantas",
     xlab = "Longitude", 
     ylab = "Latitude", 
     col=viridis(256)
    )
plot(batasbasin, col="transparent", border="black", lwd=1, add = TRUE)
linesungai <- readOGR(dsn=path.expand("D:/College/Semester8/data/das"),
                            layer="linebengawansolobrantas")
plot(linesungai, col="blue", border="black", lwd=1, add = TRUE)
# Out:
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "DasBrantasBengawansolo"
# with 2 features
# It has 10 fields
# OGR data source with driver: ESRI Shapefile
# Source: "D:\College\Semester8\data\das", layer: "linebengawansolobrantas"
# with 85 features
# It has 23 fields
# Plot with title "Kecepatan rata2 per tahun GWS GLDAS(mm)
#  Basin Bengawan Solo dan Brantas"

# %%
ff
# Out:
#   [1] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050101-20050131.180W_60S_180E_90N.tif"
#   [2] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050201-20050228.180W_60S_180E_90N.tif"
#   [3] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050301-20050331.180W_60S_180E_90N.tif"
#   [4] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050401-20050430.180W_60S_180E_90N.tif"
#   [5] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050501-20050531.180W_60S_180E_90N.tif"
#   [6] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050601-20050630.180W_60S_180E_90N.tif"
#   [7] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050701-20050731.180W_60S_180E_90N.tif"
#   [8] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050801-20050831.180W_60S_180E_90N.tif"
#   [9] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20050901-20050930.180W_60S_180E_90N.tif"
#  [10] "D:/College/Semester8/data/analisa/gws/monthly/GIOVANNI-g4.timeAvgMap.GLDAS_CLSM025_DA1_D_2_2_GWS_tavg.20051001-20051031.180W_60S_180E_90N.tif"
